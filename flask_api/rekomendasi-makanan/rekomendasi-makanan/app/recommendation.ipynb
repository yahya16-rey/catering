# %%
import pandas as pd
import joblib

# ==========================================
# LOAD DATASET
# ==========================================

df = pd.read_csv('../dataset/menu.csv')

# ==========================================
# LOAD MODEL
# ==========================================

tfidf = joblib.load('../model/tfidf_vectorizer.pkl')

cosine_sim = joblib.load('../model/cosine_similarity.pkl')

indices = joblib.load('../model/menu_indices.pkl')

# ==========================================
# FUNCTION RECOMMENDATION
# ==========================================

def recommend_menu(nama_menu, top_n=5):

    idx = indices[nama_menu]

    sim_scores = list(enumerate(cosine_sim[idx]))

    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    sim_scores = sim_scores[1:top_n+1]

    menu_indices = [i[0] for i in sim_scores]

    hasil = df[
        ['nama_menu', 'kategori', 'harga', 'gambar']
    ].iloc[menu_indices]

    return hasil

# ==========================================
# TEST
# ==========================================

hasil = recommend_menu('Nasi Ayam Bakar')

print(hasil)
# Out:
#            nama_menu kategori  harga  gambar
# 22        Nasi Bakar     nasi  22000  23.png
# 21    Nasi Ayam Uduk     nasi  23000  22.png
# 18  Nasi Ayam Geprek     nasi  22000  19.png
# 20        Nasi Katsu     nasi  25000  21.png
# 23       Nasi Goreng     nasi  20000  24.png

# %%
pip install scikit-learn==1.6.1
# Out:
# Requirement already satisfied: scikit-learn==1.6.1 in c:\users\yahya\appdata\local\programs\python\python310\lib\site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\yahya\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn==1.6.1) (2.1.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\yahya\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn==1.6.1) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\yahya\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn==1.6.1) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\yahya\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn==1.6.1) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.1
# [notice] To update, run: C:\Users\Yahya\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip
